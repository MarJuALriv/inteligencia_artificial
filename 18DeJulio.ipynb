# %% [markdown]
# <a href="https://colab.research.google.com/github/MarJuALriv/inteligencia_artificial/blob/master/18DeJulio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print(pd.__version__)

serieData=pd.Series(data=[100,200,300], index=['fernando', 'pedro', 'lucas'])
print(serieData)

print(serieData['fernando'])

print (serieData.index)

print('fernando' in serieData)
# Out:
# 2.0.3
# fernando    100
# pedro       200
# lucas       300
# dtype: int64
# 100
# Index(['fernando', 'pedro', 'lucas'], dtype='object')
# True

# %%
import pandas as pd

myDiccionario = {
    'one': pd.Series([100, 200, 300], index=['fernando', 'pedro', 'lucas']),
    'two': pd.Series([11, 12, 33], index=['julio', 'pedro', 'lucas'])
}

# SERIES Y DATAFRAMES
df = pd.DataFrame(myDiccionario)
print(df)

print(df.index)
print(df)
print('we are here............')
print(df.index)
print(df.columns)

print(df['two']['julio'])
# Out:
#             one   two
# fernando  100.0   NaN
# julio       NaN  11.0
# lucas     300.0  33.0
# pedro     200.0  12.0
# Index(['fernando', 'julio', 'lucas', 'pedro'], dtype='object')
#             one   two
# fernando  100.0   NaN
# julio       NaN  11.0
# lucas     300.0  33.0
# pedro     200.0  12.0
# we are here............
# Index(['fernando', 'julio', 'lucas', 'pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# 11.0

# %%
import pandas as pd
df = pd.read_csv('/content/movies.csv')

# %%
df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
df.tail(6)
# Out:
#        movieId                           title                  genres
# 62417   209155      Santosh Subramaniam (2008)   Action|Comedy|Romance
# 62418   209157                       We (2018)                   Drama
# 62419   209159       Window of the Soul (2001)             Documentary
# 62420   209163                Bad Poems (2018)            Comedy|Drama
# 62421   209169             A Girl Thing (2001)      (no genres listed)
# 62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama

# %%
del df['genres']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genres'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
# [62423 rows x 2 columns]

# %%
df.shape
# Out:
# (62423, 2)

# %%
df.columns
# Out:
# Index(['movieId', 'title'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=62423, step=1)

# %%
tmp=df.iloc[255]

# %%
tmp
# Out:
# movieId                                     258
# title      Kid in King Arthur's Court, A (1995)
# Name: 255, dtype: object

# %%
tmp['movieId']
# Out:
# 258

# %%
'movieId' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      movieId                 title
# 100      102      Mr. Wrong (1996)
# 200      202  Total Eclipse (1995)
# 300      304      Roommates (1995)

# %%
df.describe()
# Out:
#              movieId
# count   62423.000000
# mean   122220.387646
# std     63264.744844
# min         1.000000
# 25%     82146.500000
# 50%    138022.000000
# 75%    173222.000000
# max    209171.000000

# %%
min_movieid = df['movieId'].min()
max_movieid = df['movieId'].max()
mean_movieid = df['movieId'].mean()

print("Valor mínimo de movieId:", min_movieid)
print("Valor máximo de movieId:", max_movieid)
print("Valor promedio de movieId:", mean_movieid)
# Out:
# Valor mínimo de movieId: 1
# Valor máximo de movieId: 209171
# Valor promedio de movieId: 122220.38764557935
